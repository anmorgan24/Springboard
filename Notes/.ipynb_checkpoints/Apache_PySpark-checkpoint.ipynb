# %% [markdown]
# # Apache PySpark by Example
# **Instructor**: Jonathan Fernandes

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
def show_image(image, title='Image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# * Spark runs locally, as well as in a cluster, on premise, or in a cloud.
# * Spark runs on top of Hadoop YARN
# * Spark is primarily written in Scala on JVMs
#     * Scala is the default language, but you can also use:
#         * Java
#         * Python
#         * R
#         * SQL
#
# * Apache Mesos stand-alone
# * Apache Mesos (in the cloud-Amazon)
# * Spark Core API is the foundation of the Spark ecosystem:
#     * Spark SQL
#     * Streaming
#     * MLlib
#     * GraphX: lets you make sense of graph-structured data at scale
#
# #### Spark Core API
# * Task scheduling
# * Memory management
# * Fault recovery
# * Interacting with storage systems
#
# #### Spark SQL and DataFrames
# * Spark SQL can act as a Distributed Query Engine
# * DataFrame programming abstraction
# * Complex analytics with SQL $\Downarrow$
# * Spark SQL allows you to intermix SQL's queries with the programmatic data manipulations supported by lower-level APIs in Python, Java, and Scala all within a single application and so combining SQL with complex analytics
#
# #### Spark Streaming
# * Process real-time data
# * Analyze streaming and historical data
# * Use similar code for batch data and real-time data
#
# #### MLlib
# * The machine-learning model built on top of Spark is a scalable ML library that delivers both high-quality algorithms  and a fast speed
# * Works in memory
# * Fast; can be 100x faster than MapReduce
#
# #### GraphX
# * A graph computation engine built on top of Spark that enables users to interactively build, transform, and reason about graph structure data at scale
# * Comes with a library of common algorithms
# * Introduces a new graph abstraction, the **directed multigraph** (*recall from Intro to Networks with NetworkX*)
# * Useful for visualizing social networks, etc
#
# #### PySpark
# * Recall that Spark is written in Scala
# * PySpark is just a Python wrapper around the Spark core
# * Alternatives to PySpark:
#     * **pandas:**
#         * tabular data
#         * can handle hundreds of thousands to millions of rows
#         * mature and feature-rich
#         * Limited to a single machine
#     * **Hadoop:** (a distributed cluster, why not Hadoop instead of Spark?)
#         * Until a couple of years ago, Hadoop was THE big data platform
#         * Compute system: MapReduce
#         * Compute system and storage system (Hadoop file system) closely integrated
#         * Closely integrated and really difficult to run one without the other; public cloud is one example of this (whereas Spark can be used on Hadoop storage or on a cloud).
#         * HDFS (Hadoop Distributed File System) and replication (are self-healing)
#         * One of the key differences between Spark and Hadoop lies in their approach to processing; Spark can process in memory, while Hadoop MapReduce has to read from and write to a disk.
#             * As a result the processing speed of each can differ significantly (with Spark being up to 100x faster)
#             * General rule of thumb: Hadoop requires more memory on disk and Spark requires more RAM.
#                 * Meaning that setting up Spark clusters can be more expensive
#                 * Hadoop to be used mainly for disc heavy operations with the MapReduce paradigm
#                 * Spark tends to be more flexible, but more costly in memory processing architecture
#     * **Dask:** a library for parallel computing in Python
#         * Only written in Python
#         * only really supports Python
#         * Spark and Dask can both scale from a single node to a 1,000 node cluster
# * **Recall:** PySpark is written in Scala, but has support for Java, Python, R, and Scala, and interoperates well with JVM code

# %%
show_image(imread('data/spark_vs_dask.png'), "Spark vs. Dask")

# %% [markdown]
# * Spark originally developed in UCBerkeley's amplab: they had been working in Hadoop, and so they knew that MapReduce was inefficient for iterative and interactive computing jobs
# * So right from the beginning, Spark was designed to be fast for interactive queries and iterative algorithms.
# * UCBerkeley donated Spark to Apache Open Source
# * A couple of the original developers created their own company: Databricks
# * So what's different about Databricks version of Apache Spark?
#     * Databricks offers Apache Spark but with a platform that unifies the Data Science and Data Engineering
#     * It provides an optimized version of Apache Spark
#     * Offers interactive notebooks

# %% [markdown]
# #### Spark Components

# %%
show_image(imread('data/spark_components.png'), "Spark Components")

# %% [markdown]
# Cluster Manager = Task Manager/ Resource Manager
#
# #### Cluster Manager Types
# * Standalone
# * Apache Mesos
# * Hadoop YARN
# * Kubernetes: if you want to automate the deployment and management of containerized applications
#
# #### Creating a Spark session
# * Creating a Spark session is the first step of any Spark appication
# * The Spark context allows you to communicate with some of Spark's lower-level APIs, such as RDDs
# * The SQL context gives you access to higher-level APIs, such as the Spark SQL.
# * With Spark 2.0, a Spark session can access all of Spark's functionality through a single unified point of entry.
# * As of Spark version 2.0, the functionality previously available only through the Spark context and the SQL context is now available via the SparkSession
#     * The SparkSession is now your single, unified entry point to manipulate data with Spark
#
# #### Partitions
# * Spark is a distributed system, meaning that if we want the workers to work in parallel, Spark needs to break the data into chunks, or *partitions*.
# * A **partition** is a collection of rows from your DataFrame that sits on one machine in your cluster
# * Because you're working with a higher-level API when using DataFrames, you don't normally get involved with manipulating the partitions manually
#
# #### Transformations
# * **Transformation** modify the DataFrame.
# * Transformations are a core data structure in Spark and are immutable
# * The instructions that we use to modify the DataFrame are known as **transformations**.
# * This could be a filter operation or a distinct operations, where you only get the unique values in a certain column
# * You'll find that when we perform transformation operations, nothing seems to happen
# * **Spark doesn't act on transformations until we perform actions**
# * This "waiting until the last moment to do the work" is known as **lazy evaluation**.
#     * Very helpful, because it allows Spark to create a streamlied plan, allowing it to run as efficiently as possible across the cluster
#     * Makes a lot of sense for big data jobs
#
# #### Actions
# * An action tells Spark to compute the results of these transformations and there are three types
#     #### View Data
#     * Allow us to view data in our console
#     * `.show()`
#     #### Collect Data
#     * Allow us to collect data to youe driver
#     * `.collect()`
#     #### Write Data
#     * Allow us to write to output data sources
#     * `.write.format(...)`
#
# #### Google Colab
# * Hosts Jupyter notebooks in the cloud
# * Free
# * Requires no set-up
# * Works with most major browsers (Chrome, Firefox desktop versions recommended)
# * Supports .ipynb files
# * Colab notebooks are very similar to Jupyter notebooks; you can upload or import an existing Jupyter or IPython notebook into Colab
# * Colab notebooks are also stored in the open source Jupyter Notebook format (.ipynb)
# * Supports shell commands
# * Supports common Linux commands like `!wget` and `!pwd`
# * Executes code in a VM dedicated to your account
# * Stores notebooks in Google Drive, where they can be shared, edited, and commented on collaboratively

# %% [markdown]
# * There are two main APIs that we'll be looking at in this course:
#     * **DataFrames** $\Rightarrow$ High-level APIs
#     * **Resilient Distributed Datasets (RDDs)** $\Rightarrow$ Low-level APIs
# * **Recall:** In *Spark*, a DataFrame is a distributed collection of objects of type row; you can think of this as a table in a relational database, except a Spark DataFrame could sit across hundreds of computers
#
# #### Dataset API
# * **Datasets** are used with statically-typed languages, like Java or Scala
# * Because Python is a dynamically-typed language, it doesn't support the dataset API
#
# #### PySpark syntax for pandas calls:
#
# * **`df.head(n)`:**
# * `df.take(n)` shows n elements; calls collect on the limit function, or: `.limit(n).collect()`; returns a list
# * `df.collect()` returns ALL
# * `df.show(n)` returns in nice, presentable format; prints data in a nice format
# * `df.limit(n)` returns n rows as a dataframe
# * `df.head(n)` returns n rows as an array; returns the take function; returns a list

# %% [markdown]
# ### Schemas
# * A **schema** defines the column names, and then what datatype they are (int, str, datetime... etc.)
# * `df.types`
# * `df.dtypes`
# * `df.printSchema()`
# * Spark can infer the schema by default by taking a look at a couple of row of the data, but explicitly defining the schema in Spark is recommended
# * To define a schema, import the different data typse from `pyspark.sql.types`
#
# ### Columns
# * access with traditional dot or bracket notation
# * However, we can't always use the dot notation method because this will break when/if the column names have reserved names or are attributes to the DataFrame class.
#     * `df.column1`
#     * `df['column1`]
#     * `df.select(col('column1'))`
#
# #### Select multiple columns in PySpark
# * `df.select('column1', 'column2').show(3)`
# #### Add a column in PySpark
# * `df.withColumn('DoubleColumn', 2*df['Acolumn'])`
# #### Rename a column in PySpark
# * `df.withColumnRenamed(ExistingColumnName, NewColumnName)`
# * **Note** that renaming a column provides a new DataFrame
# * If you attempt to rename a column that doesn't exist, then no operation is performed
# #### Remove columns in PySpark
# * `df.drop('columnName')`
# * `df.drop('columnName1', 'columnName2', 'columnName3')
# * **Note** that, again, this returns a *new* DataFrame with the specified column dropped
# * If you attempt to drop a column that doesn't exist (for example, with a typo), then no operation will be performed
# #### Group by a column in PySpark
# * `df.groupBy('column')`

# %% [markdown]
# ### Working with rows in PySpark
#
# #### Filtering Rows in PySpark
# * `df.filter(col('column') > 1)`
# #### Get unique rows for a column in PySpark
# * `df.select(column).distinct().show()`
# #### Sort rows in PySpark
# * `df.orderBy(col('column'))`
# #### Append Rows in PySpark
# * Since dfs are immutable in PySpark, you can't just add rows to a df
# * Instead you have to `union` the original dataframe with a new one
# * This concatenates two dfs, and you need to make sure that both dfs have the same number of columns and the same schema, otherwise the union will fail
# * `df.union(df2)`

# %% [markdown]
# ### Functions
# * In PySpark, the built-in functions are available from the `pyspark.sql.functions` library
#     * Example: `from pyspark.sql.functions import mean`
#
# ### User-Defined Functions (UDFs)
# * You can create your own functions
# * However, **built-in fucntions are performant.**
# * **Once you create your funciton, you need to register it with Spark for it to be used on all the worker nodes.**
# * You can create functions in Java, Scala, Python, R, or SQL.
# * Whichever language you use, you need to serialize the function on the driver and then send it out to all of the executive processors
# * If written in Scala or Java, it can be used in the JVM (ie little performance penalty)
# * Python will start a process on the worker
#     * The real performance hit is in serializing the function to Python
# * Generally **avoid all Python user-defined functions** (can/likely will lead to nodes crashing)
# #### Options for UDFs
# * For performance, write functions in Scala or Java
# * You can still access and use this function from Python

# %% [markdown]
# ### Join
# * A **join** brings together two sets of data
# * **Join types:**
#     * Inner joins: keeps rows that exist in both datasets
#     * Outer joins: keeps rows with keys in either dataset
#     * Left outer joins: keeps rows with keys in the left dataset
#     * Right outer joins: Keep rows with keys in the right dataset
#
# ### PySpark Join Syntax
# * `df.join(df2, df.column == df.column, how = {'inner'})`

# %% [markdown]
# # Pre-processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import geopandas as gpd
from datetime import datetime
import ipywidgets as widgets
from ipywidgets import interact
import pycaret
from pycaret.regression import *
from statsmodels.tsa.stattools import adfuller
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from IPython import display

# %%
#load dataframe
#parse datetime column
df=pd.read_csv('~/Test/Springboard/Capstone_COVID19_Weather/Data/state_cov_weather2.csv', parse_dates=[0])
df.set_index('date', inplace= True)

# %%
df.head()
# Out:
#             VT_Avg_Temp(F)  VT_PRCP(mm)  ME_Avg_Temp(F)  ME_PRCP(mm)  \
# date
# 2020-03-01           19.58          0.3           14.18          0.3
# 2020-03-02           32.00          0.0           17.06          4.6
# 2020-03-03           44.06          2.8           39.56          0.0
# 2020-03-04           41.54          0.0           32.00          6.6
# 2020-03-05           37.04          0.0           30.02          0.0
#
#             CT_Avg_Temp(F)  CT_PRCP(mm)  MA_Avg_Temp(F)  MA_PRCP(mm)  \
# date
# 2020-03-01           26.24          0.0           26.42          0.0
# 2020-03-02           37.58          0.0           36.50          0.0
# 2020-03-03           51.26          3.8           55.94          0.0
# 2020-03-04           48.02          0.0           46.94          2.5
# 2020-03-05           43.16          0.0           42.98          0.0
#
#             CT_Conf_Cases  VT_Conf_Cases  ME_Conf_Cases  MA_Conf_Cases  \
# date
# 2020-03-01            0.0            0.0            0.0            1.0
# 2020-03-02            0.0            0.0            0.0            1.0
# 2020-03-03            0.0            0.0            0.0            1.0
# 2020-03-04            0.0            0.0            0.0            2.0
# 2020-03-05            0.0            0.0            0.0            8.0
#
#             weekday
# date
# 2020-03-01        6
# 2020-03-02        0
# 2020-03-03        1
# 2020-03-04        2
# 2020-03-05        3

# %%
df_vt=df.drop(columns=['ME_Avg_Temp(F)', 'ME_PRCP(mm)', 'ME_Conf_Cases', 'CT_Avg_Temp(F)', 'CT_PRCP(mm)', 'CT_Conf_Cases', 'MA_Avg_Temp(F)', 'MA_PRCP(mm)', 'MA_Conf_Cases','weekday'])

# %%
df_me=df.drop(columns=['VT_Avg_Temp(F)', 'VT_PRCP(mm)', 'VT_Conf_Cases', 'CT_Avg_Temp(F)', 'CT_PRCP(mm)', 'CT_Conf_Cases', 'MA_Avg_Temp(F)', 'MA_PRCP(mm)', 'MA_Conf_Cases','weekday'])

# %%
df_ma=df.drop(columns=['ME_Avg_Temp(F)', 'ME_PRCP(mm)', 'ME_Conf_Cases', 'CT_Avg_Temp(F)', 'CT_PRCP(mm)', 'CT_Conf_Cases', 'VT_Avg_Temp(F)', 'VT_PRCP(mm)', 'VT_Conf_Cases','weekday'])

# %%
df_ct= df.drop(columns=['ME_Avg_Temp(F)', 'ME_PRCP(mm)', 'ME_Conf_Cases', 'VT_Avg_Temp(F)', 'VT_PRCP(mm)', 'VT_Conf_Cases', 'MA_Avg_Temp(F)', 'MA_PRCP(mm)', 'MA_Conf_Cases','weekday'])

# %% [markdown]
# ***

# %%
# Make duplicates of datasets for processing with Pycaret:
df_vt3 = df_vt.reset_index()
df_ct3 = df_ct.reset_index()
df_me3 = df_me.reset_index()
df_ma3 = df_ma.reset_index()

# %%
df_list = [df_ct3, df_ma3, df_me3, df_vt3]

# %%
# Add 'day_of_week' and 'day_of_year' columns to each dataframe
for df in df_list:
    df['day_of_week'] = [i.dayofweek for i in df['date']]
    df['day_of_year'] = [i.dayofyear for i in df['date']]
    df['Year'] =[i.year for i in df['date']]
    df['Month'] = [i.month for i in df['date']]
    df['Day'] = [i.day for i in df['date']]

# %% [markdown]
# ### US Census Bureau state populations
# * Massachusetts: 7,029,917
# * Vermont: 643,077
# * Connecticut: 3,605,944
# * Maine: 1,362,359
#
# Source: [U.S. Census Bureau](https://www.census.gov/quickfacts/fact/table/VT,CT,MA,ME/PST045219) April 1, 2020 Census.
#
# Because some states are very densely populated, while others are much more sparsely populated, I'll calculate confirmed Covid cases as a percentage of overall population.
#
# In order to do this, I'll divide by the appropriate state's total population (as per the April 1, 2020 U.S. Census Bureau), and multiply by 100,000 for ten thousandths of a percent.

# %%
df_ma3['new_case_percent_pop*'] = (df_ma3['MA_Conf_Cases'] / 70.29917)

# %%
df_ct3['new_case_percent_pop*'] = (df_ct3['CT_Conf_Cases'] / 36.05944)

# %%
df_me3['new_case_percent_pop*'] = (df_me3['ME_Conf_Cases'] / 13.62359)

# %%
df_vt3['new_case_percent_pop*'] = (df_vt3['VT_Conf_Cases'] / 6.43077)

# %% [markdown]
# Try the model using new cases as ten thousandths of a percent of population, rather than count.

# %% [markdown]
# ## Using the mean as a baseline prediction model

# %% [markdown]
# #### Massachusetts

# %%
# Create features
X_ma, y_ma = df_ma3.drop('MA_Conf_Cases', axis =1), df_ma3.MA_Conf_Cases
# Make test and training split
X_train_ma, X_test_ma, y_train_ma, y_test_ma = train_test_split(X_ma, y_ma, test_size = 0.2, random_state=42)
dummy_mean_ma = DummyRegressor(strategy='mean')
# "Train" dummy regressor
dummy_mean_ma.fit(X_train_ma, y_train_ma)
# Get R-squared score
score_mean_ma = dummy_mean_ma.score(X_test_ma, y_test_ma) 
print("The R2 score of using the mean to predict Massachusetts' COVID19 cases is:", score_mean_ma)
# Out:
# The R2 score of using the mean to predict Massachusetts' COVID19 cases is: -0.053284810131488225

# %% [markdown]
# #### Connecticut

# %%
# Create features
X_ct, y_ct = df_ct3.drop('CT_Conf_Cases', axis =1), df_ct3.CT_Conf_Cases
# Make test and training split
X_train_ct, X_test_ct, y_train_ct, y_test_ct = train_test_split(X_ct, y_ct, test_size=0.2, random_state=42)
# Create a dummy regressor
dummy_mean_ct = DummyRegressor(strategy='mean')
# "Train" dummy regressor
dummy_mean_ct.fit(X_train_ct, y_train_ct)
# Get R-squared score
score_mean_ct = dummy_mean_ct.score(X_test_ct, y_test_ct) 
print("The R2 score of using the mean to predict Connecticut's COVID19 cases is:", score_mean_ct)
# Out:
# The R2 score of using the mean to predict Connecticut's COVID19 cases is: -0.006702217631290974

# %% [markdown]
# #### Vermont

# %%
# Create features
X_vt, y_vt = df_vt3.drop('VT_Conf_Cases', axis = 1), df_vt3.VT_Conf_Cases
# Make test and training split
X_train_vt, X_test_vt, y_train_vt, y_test_vt = train_test_split(X_vt, y_vt, test_size = 0.2,random_state=42)
# Create a dummy regressor
dummy_mean_vt = DummyRegressor(strategy='mean')
# "Train" dummy regressor
dummy_mean_vt.fit(X_train_vt, y_train_vt)
# Get R-squared score
score_mean_vt = dummy_mean_vt.score(X_test_vt, y_test_vt) 
print("The R2 score of using the mean to predict Vermont's COVID19 cases is:", score_mean_vt)
# Out:
# The R2 score of using the mean to predict Vermont's COVID19 cases is: -0.013915984644440993

# %% [markdown]
# #### Maine

# %%
# Create features
X_me, y_me = df_me3.drop('ME_Conf_Cases', axis =1), df_me3.ME_Conf_Cases
# Make test and training split
X_train_me, X_test_me, y_train_me, y_test_me = train_test_split(X_me, y_me, test_size=0.2,random_state=42)
# Create a dummy regressor
dummy_mean_me = DummyRegressor(strategy='mean')
# "Train" dummy regressor
dummy_mean_me.fit(X_train_me, y_train_me)
# Get R-squared score
score_mean_me = dummy_mean_me.score(X_test_me, y_test_me) 
print("The R2 score of using the mean to predict Maine's COVID19 cases is:", score_mean_me)
# Out:
# The R2 score of using the mean to predict Maine's COVID19 cases is: -0.10540068459291052

# %% [markdown]
# ## Correlation between COVID cases and lagged precipitation values

# %% [markdown]
# We know that there is a period of incubation between the moment of COVID-19 infection and the manifestation of symptoms, so it might be reasonable to expect a higher correlation between average temperatures and some lagged value of COVID-19 cases. If COVID-19 infection rates truly are correlated with temperature, cases that got tested *because* they manifested symptoms, would likely demonstrate some lag with the temperature on the day they were infected. On the other hand, those cases that get tested regularly (for work, medical reasons, etc.), may not demonstrate much of a lag, if any at all, with the temperature on the day they were infected. It would be worthwhile to explore lagged values of COVID cases to determine if there isn't a higher correlation with a lagged value of cases than with the current value of COVID-19 cases.

# %% [markdown]
# #### Massachusetts temperature lag cross-correlation

# %%
df_ma4=df_ma3.copy()

# %%
prcp_cov_lags = {'1_wk': -7, '1.5_wks': -10, '2_wks': -14, '3_wks': -21, '4_wks': -28}
for key, value in prcp_cov_lags.items():
    df_ma4[key] = df_ma4['MA_Conf_Cases'].shift(value, axis=0)
df_ma4 = df_ma4.drop(['MA_Avg_Temp(F)', 'day_of_week', 'day_of_year', 'Year', 'Month', 'Day'], axis =1).dropna()
ma_corr = pd.DataFrame(df_ma4.corr())
ma_corr
# Out:
#                        MA_PRCP(mm)  MA_Conf_Cases  new_case_percent_pop*  \
# MA_PRCP(mm)               1.000000       0.009234               0.009234
# MA_Conf_Cases             0.009234       1.000000               1.000000
# new_case_percent_pop*     0.009234       1.000000               1.000000
# 1_wk                      0.020513       0.920939               0.920939
# 1.5_wks                   0.007562       0.795222               0.795222
# 2_wks                     0.032721       0.839697               0.839697
# 3_wks                     0.022007       0.747557               0.747557
# 4_wks                     0.034374       0.638274               0.638274
#
#                            1_wk   1.5_wks     2_wks     3_wks     4_wks
# MA_PRCP(mm)            0.020513  0.007562  0.032721  0.022007  0.034374
# MA_Conf_Cases          0.920939  0.795222  0.839697  0.747557  0.638274
# new_case_percent_pop*  0.920939  0.795222  0.839697  0.747557  0.638274
# 1_wk                   1.000000  0.833874  0.920121  0.838120  0.745091
# 1.5_wks                0.833874  1.000000  0.844313  0.791362  0.714971
# 2_wks                  0.920121  0.844313  1.000000  0.919334  0.835688
# 3_wks                  0.838120  0.791362  0.919334  1.000000  0.916362
# 4_wks                  0.745091  0.714971  0.835688  0.916362  1.000000

# %%
ma_corr.drop(columns=['MA_PRCP(mm)', 'new_case_percent_pop*'], inplace=True)
ma_corr.rename(columns={'MA_Conf_Cases': '0_wks'}, inplace=True)
ma_corr.loc['MA_PRCP(mm)', :].plot()
plt.title('Correlation of PRCP vs lagged COV cases: MA')
plt.xlabel('Lag time')
plt.ylabel('Correlation with PRCP')
plt.show()

# %%
df_ma4
# Out:
#           date  MA_PRCP(mm)  MA_Conf_Cases  new_case_percent_pop*    1_wk  \
# 0   2020-03-01          0.0            1.0               0.014225    19.0
# 1   2020-03-02          0.0            1.0               0.014225     5.0
# 2   2020-03-03          0.0            1.0               0.014225    14.0
# 3   2020-03-04          2.5            2.0               0.028450    22.0
# 4   2020-03-05          0.0            8.0               0.113799    29.0
# ..         ...          ...            ...                    ...     ...
# 523 2021-08-10         15.7          445.0               6.330089   489.0
# 524 2021-08-11          0.0         1440.0              20.483883  1579.0
# 525 2021-08-12          0.0         1367.0              19.445464  1576.0
# 526 2021-08-13          0.0         1298.0              18.463945  1533.0
# 527 2021-08-14          0.0         1031.0              14.665892  1139.0
#
#      1.5_wks   2_wks   3_wks   4_wks
# 0       22.0    68.0   286.0   523.0
# 1       29.0   149.0   608.0  1238.0
# 2       61.0   248.0   718.0  1264.0
# 3       73.0   259.0   748.0  1339.0
# 4       68.0   278.0   935.0  1279.0
# ..       ...     ...     ...     ...
# 523   1533.0   533.0   592.0  1475.0
# 524   1139.0  1495.0  2037.0  2407.0
# 525   1139.0  1891.0  1767.0  1873.0
# 526   1139.0  1656.0  1911.0     0.0
# 527    533.0  1433.0  1894.0     0.0
#
# [528 rows x 9 columns]

# %% [markdown]
# #### Connecticut temperature lag cross-correlation

# %%
df_ct4=df_ct3.copy()

# %%
for key, value in prcp_cov_lags.items():
    df_ct4[key] = df_ct4['CT_Conf_Cases'].shift(value, axis=0)
df_ct4 = df_ct4.drop(['CT_Avg_Temp(F)', 'day_of_week', 'day_of_year', 'Year', 'Month', 'Day'], axis =1).dropna()
ct_corr = pd.DataFrame(df_ct4.corr())
ct_corr
# Out:
#                        CT_PRCP(mm)  CT_Conf_Cases  new_case_percent_pop*  \
# CT_PRCP(mm)               1.000000       0.028828               0.028828
# CT_Conf_Cases             0.028828       1.000000               1.000000
# new_case_percent_pop*     0.028828       1.000000               1.000000
# 1_wk                      0.037386       0.777177               0.777177
# 1.5_wks                  -0.018751       0.650712               0.650712
# 2_wks                     0.025447       0.727060               0.727060
# 3_wks                     0.058460       0.643448               0.643448
# 4_wks                     0.029693       0.568160               0.568160
#
#                            1_wk   1.5_wks     2_wks     3_wks     4_wks
# CT_PRCP(mm)            0.037386 -0.018751  0.025447  0.058460  0.029693
# CT_Conf_Cases          0.777177  0.650712  0.727060  0.643448  0.568160
# new_case_percent_pop*  0.777177  0.650712  0.727060  0.643448  0.568160
# 1_wk                   1.000000  0.666420  0.774834  0.724540  0.640356
# 1.5_wks                0.666420  1.000000  0.696944  0.663887  0.583644
# 2_wks                  0.774834  0.696944  1.000000  0.772775  0.721319
# 3_wks                  0.724540  0.663887  0.772775  1.000000  0.769964
# 4_wks                  0.640356  0.583644  0.721319  0.769964  1.000000

# %%
ct_corr.drop(columns=['CT_PRCP(mm)', 'new_case_percent_pop*'], inplace=True)
ct_corr.rename(columns={'CT_Conf_Cases': '0_wks'}, inplace=True)
ct_corr.loc['CT_PRCP(mm)', :].plot()
plt.title('Correlation of PRCP vs lagged COV cases: CT')
plt.xlabel('Lag time')
plt.ylabel('Correlation with PRCP')
plt.plot()
# Out:
# []

# %% [markdown]
# #### Vermont temperature lag cross-correlation

# %%
df_vt4=df_vt3.copy()

# %%
for key, value in prcp_cov_lags.items():
    df_vt4[key] = df_vt4['VT_Conf_Cases'].shift(value, axis=0)
df_vt4 = df_vt4.drop(['VT_Avg_Temp(F)', 'day_of_week', 'day_of_year', 'Year', 'Month', 'Day'], axis =1).dropna()
vt_corr = pd.DataFrame(df_vt4.corr())
vt_corr
# Out:
#                        VT_PRCP(mm)  VT_Conf_Cases  new_case_percent_pop*  \
# VT_PRCP(mm)               1.000000      -0.043127              -0.043127
# VT_Conf_Cases            -0.043127       1.000000               1.000000
# new_case_percent_pop*    -0.043127       1.000000               1.000000
# 1_wk                     -0.065671       0.844868               0.844868
# 1.5_wks                  -0.064759       0.734993               0.734993
# 2_wks                    -0.042046       0.781832               0.781832
# 3_wks                    -0.053783       0.709235               0.709235
# 4_wks                    -0.032076       0.644609               0.644609
#
#                            1_wk   1.5_wks     2_wks     3_wks     4_wks
# VT_PRCP(mm)           -0.065671 -0.064759 -0.042046 -0.053783 -0.032076
# VT_Conf_Cases          0.844868  0.734993  0.781832  0.709235  0.644609
# new_case_percent_pop*  0.844868  0.734993  0.781832  0.709235  0.644609
# 1_wk                   1.000000  0.791469  0.842056  0.782368  0.713320
# 1.5_wks                0.791469  1.000000  0.761727  0.725684  0.663498
# 2_wks                  0.842056  0.761727  1.000000  0.839935  0.779342
# 3_wks                  0.782368  0.725684  0.839935  1.000000  0.840092
# 4_wks                  0.713320  0.663498  0.779342  0.840092  1.000000

# %%
vt_corr.drop(columns=['VT_PRCP(mm)', 'new_case_percent_pop*'], inplace=True)
vt_corr.rename(columns={'VT_Conf_Cases': '0_wks'}, inplace=True)
vt_corr.loc['VT_PRCP(mm)', :].plot()
plt.title('Correlation of PRCP vs lagged COV cases: VT')
plt.xlabel('Lag time')
plt.ylabel('Correlation with PRCP')
plt.show()

# %% [markdown]
# #### Maine temperature lag cross-correlation

# %%
df_me4=df_me3.copy()

# %%
for key, value in prcp_cov_lags.items():
    df_me4[key] = df_me4['ME_Conf_Cases'].shift(value, axis=0)
df_me4 = df_me4.drop(['ME_Avg_Temp(F)', 'day_of_week', 'day_of_year', 'Year', 'Month', 'Day'], axis =1).dropna()
me_corr = pd.DataFrame(df_me4.corr())
me_corr
# Out:
#                        ME_PRCP(mm)  ME_Conf_Cases  new_case_percent_pop*  \
# ME_PRCP(mm)               1.000000       0.002177               0.002177
# ME_Conf_Cases             0.002177       1.000000               1.000000
# new_case_percent_pop*     0.002177       1.000000               1.000000
# 1_wk                      0.024677       0.895255               0.895255
# 1.5_wks                   0.092199       0.758257               0.758257
# 2_wks                     0.027075       0.800753               0.800753
# 3_wks                     0.075240       0.681238               0.681238
# 4_wks                     0.118860       0.547517               0.547517
#
#                            1_wk   1.5_wks     2_wks     3_wks     4_wks
# ME_PRCP(mm)            0.024677  0.092199  0.027075  0.075240  0.118860
# ME_Conf_Cases          0.895255  0.758257  0.800753  0.681238  0.547517
# new_case_percent_pop*  0.895255  0.758257  0.800753  0.681238  0.547517
# 1_wk                   1.000000  0.803828  0.891650  0.786226  0.664028
# 1.5_wks                0.803828  1.000000  0.807657  0.744874  0.659837
# 2_wks                  0.891650  0.807657  1.000000  0.886078  0.770015
# 3_wks                  0.786226  0.744874  0.886078  1.000000  0.872222
# 4_wks                  0.664028  0.659837  0.770015  0.872222  1.000000

# %%
me_corr.drop(columns=['ME_PRCP(mm)', 'new_case_percent_pop*'], inplace=True)
me_corr.rename(columns={'ME_Conf_Cases': '0_wks'}, inplace=True)
plt.title('Correlation of PRCP vs lagged COV cases: ME')
me_corr.loc['ME_PRCP(mm)', :].plot()
plt.xlabel('Lag time')
plt.ylabel('Correlation with PRCP')
plt.show()

# %% [markdown]
# Maine seems to have the strongest negative correlation between temperature and a 1.5 week lag of COVID-19 cases. Vermont seems to have the strongest negative correlations with current cases, as well as those lagged by two weeks. However, Massachusetts and Connecticut both very clearly have the strongest correlation between temperature and lag 0 (or, current) case values. While it seems that for some states there may be a strong correlation with lagged COVID case values, since 50-75% of the data don't show any increased correlation using lags (and the remaining 25-50% of data disagree on an optimal lagged value), let's stick with our original lag 0 COVID-19 case values.

# %%
df_ma3['PRCP_lag7wks'] = df_ma3['new_case_percent_pop*'].shift(-49, axis=0)

# %%
df_ct3['PRCP_lag7wks'] = df_ct3['new_case_percent_pop*'].shift(-49, axis=0)

# %%
df_vt3['PRCP_lag7wks'] = df_vt3['new_case_percent_pop*'].shift(-49, axis=0)

# %%
df_me3['PRCP_lag7wks'] = df_me3['new_case_percent_pop*'].shift(-49, axis=0)

# %%
df_ma3
# Out:
#           date  MA_Avg_Temp(F)  MA_PRCP(mm)  MA_Conf_Cases  day_of_week  \
# 0   2020-03-01           26.42          0.0            1.0            6
# 1   2020-03-02           36.50          0.0            1.0            0
# 2   2020-03-03           55.94          0.0            1.0            1
# 3   2020-03-04           46.94          2.5            2.0            2
# 4   2020-03-05           42.98          0.0            8.0            3
# ..         ...             ...          ...            ...          ...
# 551 2021-09-08           71.96          0.0         1475.0            2
# 552 2021-09-09           70.88          8.1         2407.0            3
# 553 2021-09-10           68.54          7.6         1873.0            4
# 554 2021-09-11           59.99          0.3            0.0            5
# 555 2021-09-12           71.42          0.0            0.0            6
#
#      day_of_year  Year  Month  Day  new_case_percent_pop*  PRCP_lag7wks
# 0             61  2020      3    1               0.014225     15.547836
# 1             62  2020      3    2               0.014225     38.293482
# 2             63  2020      3    3               0.014225     31.223697
# 3             64  2020      3    4               0.028450     38.563755
# 4             65  2020      3    5               0.113799     34.239380
# ..           ...   ...    ...  ...                    ...           ...
# 551          251  2021      9    8              20.981756           NaN
# 552          252  2021      9    9              34.239380           NaN
# 553          253  2021      9   10              26.643273           NaN
# 554          254  2021      9   11               0.000000           NaN
# 555          255  2021      9   12               0.000000           NaN
#
# [556 rows x 11 columns]

# %%
#lag_cols = ['1_wk', '1.5_wks', '2_wks', '3_wks', '4_wks']
#df_list = [df_ma4, df_ct4, df_me4, df_vt4]

# %%
#for df in df_list:
    #df.drop(columns=lag_cols, inplace=True)

# %%
#df_ma4

# %% [markdown]
# ## Merge state dataframes back into one dataframe

# %% [markdown]
# In order to do this, first we'll make a separate column in each state's dataframe indicating state_id. With this new identifier column, we'll no longer need state-specific identifiers in the column names themselves, and we can update each state's column names to mirror each other in preparation for the merge. Before we do this, we can go ahead and drop the PRCP columns for each state, as precipitation has proved to have little correlation with (and even less predictive power of) COVID19 cases.

# %%
# Create identifying state_id columns for each state df
df_ma3['state_id'] = 'MA'
df_ct3['state_id'] = 'CT'
df_vt3['state_id'] = 'VT'
df_me3['state_id'] = 'ME'

# %%
# Prepare df_ma3 for merge by updating column names
df_ma3.drop('MA_PRCP(mm)', axis=1, inplace=True)
ma_cols = {'MA_Avg_Temp(F)': 'Avg_Temp(F)',
           'MA_Conf_Cases' : 'Conf_Cases'}
df_ma3.rename(columns=ma_cols, inplace=True)

# %%
# Prepare df_ct3 for merge by updating column names
df_ct3.drop('CT_PRCP(mm)', axis=1, inplace=True)
ct_cols = {'CT_Avg_Temp(F)': 'Avg_Temp(F)',
           'CT_Conf_Cases' : 'Conf_Cases'}
df_ct3.rename(columns=ct_cols, inplace=True)

# %%
# Prepare df_vt3 for merge by updating column names
df_vt3.drop('VT_PRCP(mm)', axis=1, inplace=True)
vt_cols = {'VT_Avg_Temp(F)': 'Avg_Temp(F)',
           'VT_Conf_Cases' : 'Conf_Cases'}
df_vt3.rename(columns=vt_cols, inplace=True)

# %%
# Prepare df_me3 for merge by updating column names
df_me3.drop('ME_PRCP(mm)', axis=1, inplace=True)
me_cols = {'ME_Avg_Temp(F)': 'Avg_Temp(F)',
           'ME_Conf_Cases' : 'Conf_Cases'}
df_me3.rename(columns=me_cols, inplace=True)

# %%
df = pd.concat([df_ma3, df_me3, df_vt3, df_ct3], axis=0).set_index('date').reset_index()

# %%
df
# Out:
#            date  Avg_Temp(F)  Conf_Cases  day_of_week  day_of_year  Year  \
# 0    2020-03-01        26.42         1.0            6           61  2020
# 1    2020-03-02        36.50         1.0            0           62  2020
# 2    2020-03-03        55.94         1.0            1           63  2020
# 3    2020-03-04        46.94         2.0            2           64  2020
# 4    2020-03-05        42.98         8.0            3           65  2020
# ...         ...          ...         ...          ...          ...   ...
# 2219 2021-09-08        70.16       935.0            2          251  2021
# 2220 2021-09-09        71.42       626.0            3          252  2021
# 2221 2021-09-10        66.92       625.0            4          253  2021
# 2222 2021-09-11        63.14         0.0            5          254  2021
# 2223 2021-09-12        69.44         0.0            6          255  2021
#
#       Month  Day  new_case_percent_pop*  PRCP_lag7wks state_id
# 0         3    1               0.014225     15.547836       MA
# 1         3    2               0.014225     38.293482       MA
# 2         3    3               0.014225     31.223697       MA
# 3         3    4               0.028450     38.563755       MA
# 4         3    5               0.113799     34.239380       MA
# ...     ...  ...                    ...           ...      ...
# 2219      9    8              25.929410           NaN       CT
# 2220      9    9              17.360225           NaN       CT
# 2221      9   10              17.332493           NaN       CT
# 2222      9   11               0.000000           NaN       CT
# 2223      9   12               0.000000           NaN       CT
#
# [2224 rows x 11 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#            date  Avg_Temp(F)  Conf_Cases  day_of_week  day_of_year  Year  \
# 0    2020-03-01        26.42         1.0            6           61  2020
# 1    2020-03-02        36.50         1.0            0           62  2020
# 2    2020-03-03        55.94         1.0            1           63  2020
# 3    2020-03-04        46.94         2.0            2           64  2020
# 4    2020-03-05        42.98         8.0            3           65  2020
# ...         ...          ...         ...          ...          ...   ...
# 2170 2021-07-20        75.02        73.0            1          201  2021
# 2171 2021-07-21        75.02       228.0            2          202  2021
# 2172 2021-07-22        71.42       295.0            3          203  2021
# 2173 2021-07-23        71.96       212.0            4          204  2021
# 2174 2021-07-24        70.70       196.0            5          205  2021
#
#       Month  Day  new_case_percent_pop*  PRCP_lag7wks state_id
# 0         3    1               0.014225     15.547836       MA
# 1         3    2               0.014225     38.293482       MA
# 2         3    3               0.014225     31.223697       MA
# 3         3    4               0.028450     38.563755       MA
# 4         3    5               0.113799     34.239380       MA
# ...     ...  ...                    ...           ...      ...
# 2170      7   20               2.024435     25.929410       CT
# 2171      7   21               6.322894     17.360225       CT
# 2172      7   22               8.180937     17.332493       CT
# 2173      7   23               5.879182      0.000000       CT
# 2174      7   24               5.435470      0.000000       CT
#
# [2028 rows x 11 columns]

# %%
# save the data to a new csv file
#df.to_csv('COVID19_modeling.csv')

# %% [markdown]
# ## Mapping with geopandas

# %%
fp = '~/Test/Springboard/Capstone_COVID19_Weather/Data/geo_export/geo_export_13390475-3a1c-4c1a-b57d-965976a165df.shp'
states = (gpd.read_file(fp)).to_crs("EPSG:3395")

# %%
states2= states.copy()

# %%
states2.drop(columns=['drawseq'], inplace=True)

# %%
cov_states = states2[states2['state_abbr'].isin(['MA', 'ME', 'CT', 'VT'])]

# %%
cov_states
# Out:
#    state_abbr state_fips     state_name   sub_region  \
# 3          ME         23          Maine  New England
# 8          VT         50        Vermont  New England
# 14         CT         09    Connecticut  New England
# 17         MA         25  Massachusetts  New England
#
#                                              geometry
# 3   MULTIPOLYGON (((-7767570.862 5447191.845, -777...
# 8   POLYGON ((-8155049.965 5244387.968, -8156298.4...
# 14  POLYGON ((-8185365.825 5061422.121, -8183891.3...
# 17  MULTIPOLYGON (((-7939231.306 5098444.108, -794...

# %%
new_df = pd.DataFrame({'state_abbr':['MA', 'ME', 'CT', 'VT'],
        'total_cases':[df_ma4['MA_Conf_Cases'].sum(), df_me4['ME_Conf_Cases'].sum(), 
                       df_ct4['CT_Conf_Cases'].sum(), df_vt4['VT_Conf_Cases'].sum()]})

# %%
new_df = pd.merge(cov_states, new_df, on='state_abbr')

# %%
new_df
# Out:
#   state_abbr state_fips     state_name   sub_region  \
# 0         ME         23          Maine  New England
# 1         VT         50        Vermont  New England
# 2         CT         09    Connecticut  New England
# 3         MA         25  Massachusetts  New England
#
#                                             geometry  total_cases
# 0  MULTIPOLYGON (((-7767570.862 5447191.845, -777...     72173.75
# 1  POLYGON ((-8155049.965 5244387.968, -8156298.4...     26197.50
# 2  POLYGON ((-8185365.825 5061422.121, -8183891.3...    336545.00
# 3  MULTIPOLYGON (((-7939231.306 5098444.108, -794...    736256.50

# %%
def map_col(col, df, title):
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(22, 14))
    # create map
    df.plot(column=col, cmap='flare', legend=True, linewidth=0.8, ax=ax, edgecolor='0.8')
    # remove the axis
    ax.axis('off')
    # add a title
    ax.set_title(title, fontdict={'fontsize': '14', 'fontweight' : '3'})
    df.apply(lambda x: ax.annotate(s=x.state_name, xy=x.geometry.centroid.coords[0], ha='center', fontsize=14, color='#ffe6cc'),axis=1)
    plt.show()

# %%
map_col('total_cases', new_df, 'Total COVID19 cases per state')

# %%
start_date = datetime(2020, 3, 1)
end_date = datetime(2021, 9, 12)

dates = pd.date_range(start_date, end_date, freq='D')

options = [(date.strftime('%d/%m/%Y'), date) for date in dates]
index = (0, len(options)-1)

selection_range_slider = widgets.SelectionRangeSlider(
    options=options,
    index=index,
    description='Date',
    orientation='horizontal',
    layout={'width': '600px'}
)

#selection_range_slider

# %%
merged_df = pd.DataFrame()
for i in df.date.unique():
    mergetemp =cov_states.merge(df[df.date==i],left_on='state_abbr' ,right_on='state_id',how='left')
    merged_df = merged_df.append(mergetemp)
def cov_plot(date):
    merged_df[merged_df.date==date[0]].plot(column='new_case_percent_pop*',figsize=(20,9), legend = True)

interact(cov_plot,date=selection_range_slider)
# Out:
# interactive(children=(SelectionRangeSlider(description='Date', index=(0, 560), layout=Layout(width='600px'), o…
# <function __main__.cov_plot(date)>

# %% [markdown]
# ## Moving average plots

# %%
'''
for i in df['state_id'].unique():
    subset = df[df['state_id'] == i]
    subset.loc[:,'moving_average'] = subset['new_case_percent_pop*'].rolling(7).mean()
    fig = px.line(subset, x="date", y=["new_case_percent_pop*","moving_average"], title = (i + ' weekly rolling average'), template = 'plotly_dark')
    fig.show()
    #plt.savefig(i)
    #plt.show()
'''
# Out:
# '\nfor i in df[\'state_id\'].unique():\n    subset = df[df[\'state_id\'] == i]\n    subset.loc[:,\'moving_average\'] = subset[\'new_case_percent_pop*\'].rolling(7).mean()\n    fig = px.line(subset, x="date", y=["new_case_percent_pop*","moving_average"], title = (i + \' weekly rolling average\'), template = \'plotly_dark\')\n    fig.show()\n    #plt.savefig(i)\n    #plt.show()\n'

# %%
display.Image("Data/png/MA_weekly_rolling_average_cases.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/MA_weekly_rolling_average_cases.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/MA_weekly_rolling_average_cases.png'

# %%
display.Image("Data/png/ME_weekly_rolling_average_cases.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/ME_weekly_rolling_average_cases.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/ME_weekly_rolling_average_cases.png'

# %%
display.Image("Data/png/VT_weekly_rolling_average_cases.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/VT_weekly_rolling_average_cases.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/VT_weekly_rolling_average_cases.png'

# %%
display.Image("Data/png/CT_weekly_rolling_average_cases.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/CT_weekly_rolling_average_cases.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
# -> 1295             raise FileNotFoundError(
#    1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#
# FileNotFoundError: No such file or directory: 'Data/png/CT_weekly_rolling_average_cases.png'

# %%
'''
for i in df['state_id'].unique():
    subset = df[df['state_id'] == i]
    subset.loc[:,'moving_average'] = subset['new_case_percent_pop*'].rolling(14).mean()
    fig = px.line(subset, x="date", y=["new_case_percent_pop*","moving_average"], title = (i + ' weekly rolling average'), template = 'plotly_dark')
    fig.show()
'''
# Out:
# '\nfor i in df[\'state_id\'].unique():\n    subset = df[df[\'state_id\'] == i]\n    subset.loc[:,\'moving_average\'] = subset[\'new_case_percent_pop*\'].rolling(14).mean()\n    fig = px.line(subset, x="date", y=["new_case_percent_pop*","moving_average"], title = (i + \' weekly rolling average\'), template = \'plotly_dark\')\n    fig.show()\n'

# %% [markdown]
# ## Determining optimal models with pycaret

# %%
df.dtypes
# Out:
# date                     datetime64[ns]
# Avg_Temp(F)                     float64
# Conf_Cases                      float64
# day_of_week                       int64
# day_of_year                       int64
# Year                              int64
# Month                             int64
# Day                               int64
# new_case_percent_pop*           float64
# PRCP_lag7wks                    float64
# state_id                         object
# dtype: object

# %%
all_ts = df['state_id'].unique()

all_results = []
#final_model = {}

for i in all_ts:
    df_subset = df[df['state_id'] == i]
    
    # initialize setup from pycaret.regression
    s = setup(df_subset, target ='new_case_percent_pop*' , train_size = 0.8,
              data_split_shuffle = True, fold = 3,
              ignore_features = ['date', 'Conf_Cases'],
              numeric_features = ['day_of_year', 'Year', 'Avg_Temp(F)', 'PRCP_lag7wks'],
              categorical_features = ['Month', 'day_of_week'],
              silent = True, verbose = False, session_id = 123, normalize=False)
    # compare all models and select best one based on MAE
    best_model = compare_models(sort = 'R2', verbose=False)
    
    # capture the compare result grid and store best model in list
    p = pull().iloc[0:1]
    p['time_series'] = str(i)
    all_results.append(p)
best = compare_models(sort = 'R2')
best
# Out:
# <style  type="text/css" >
#     #T_099b9_ th {
#           text-align: left;
#     }#T_099b9_row0_col0,#T_099b9_row0_col5,#T_099b9_row0_col6,#T_099b9_row1_col0,#T_099b9_row1_col1,#T_099b9_row1_col2,#T_099b9_row1_col3,#T_099b9_row1_col4,#T_099b9_row1_col5,#T_099b9_row1_col6,#T_099b9_row2_col0,#T_099b9_row2_col1,#T_099b9_row2_col2,#T_099b9_row2_col3,#T_099b9_row2_col4,#T_099b9_row2_col6,#T_099b9_row3_col0,#T_099b9_row3_col1,#T_099b9_row3_col2,#T_099b9_row3_col3,#T_099b9_row3_col4,#T_099b9_row3_col5,#T_099b9_row3_col6,#T_099b9_row4_col0,#T_099b9_row4_col1,#T_099b9_row4_col2,#T_099b9_row4_col3,#T_099b9_row4_col4,#T_099b9_row4_col5,#T_099b9_row4_col6,#T_099b9_row5_col0,#T_099b9_row5_col1,#T_099b9_row5_col2,#T_099b9_row5_col3,#T_099b9_row5_col4,#T_099b9_row5_col5,#T_099b9_row5_col6,#T_099b9_row6_col0,#T_099b9_row6_col1,#T_099b9_row6_col2,#T_099b9_row6_col3,#T_099b9_row6_col4,#T_099b9_row6_col5,#T_099b9_row6_col6,#T_099b9_row7_col0,#T_099b9_row7_col1,#T_099b9_row7_col2,#T_099b9_row7_col3,#T_099b9_row7_col4,#T_099b9_row7_col5,#T_099b9_row7_col6,#T_099b9_row8_col0,#T_099b9_row8_col1,#T_099b9_row8_col2,#T_099b9_row8_col3,#T_099b9_row8_col4,#T_099b9_row8_col5,#T_099b9_row8_col6,#T_099b9_row9_col0,#T_099b9_row9_col1,#T_099b9_row9_col2,#T_099b9_row9_col3,#T_099b9_row9_col4,#T_099b9_row9_col5,#T_099b9_row9_col6,#T_099b9_row10_col0,#T_099b9_row10_col1,#T_099b9_row10_col2,#T_099b9_row10_col3,#T_099b9_row10_col4,#T_099b9_row10_col5,#T_099b9_row10_col6,#T_099b9_row11_col0,#T_099b9_row11_col1,#T_099b9_row11_col2,#T_099b9_row11_col3,#T_099b9_row11_col4,#T_099b9_row11_col5,#T_099b9_row11_col6,#T_099b9_row12_col0,#T_099b9_row12_col1,#T_099b9_row12_col2,#T_099b9_row12_col3,#T_099b9_row12_col4,#T_099b9_row12_col5,#T_099b9_row13_col0,#T_099b9_row13_col1,#T_099b9_row13_col2,#T_099b9_row13_col3,#T_099b9_row13_col4,#T_099b9_row13_col5,#T_099b9_row13_col6,#T_099b9_row14_col0,#T_099b9_row14_col1,#T_099b9_row14_col2,#T_099b9_row14_col3,#T_099b9_row14_col4,#T_099b9_row14_col5,#T_099b9_row14_col6,#T_099b9_row15_col0,#T_099b9_row15_col1,#T_099b9_row15_col2,#T_099b9_row15_col3,#T_099b9_row15_col4,#T_099b9_row15_col5,#T_099b9_row15_col6,#T_099b9_row16_col0,#T_099b9_row16_col1,#T_099b9_row16_col2,#T_099b9_row16_col3,#T_099b9_row16_col4,#T_099b9_row16_col5,#T_099b9_row16_col6,#T_099b9_row17_col0,#T_099b9_row17_col1,#T_099b9_row17_col2,#T_099b9_row17_col3,#T_099b9_row17_col4,#T_099b9_row17_col5,#T_099b9_row17_col6,#T_099b9_row18_col0,#T_099b9_row18_col1,#T_099b9_row18_col2,#T_099b9_row18_col3,#T_099b9_row18_col4,#T_099b9_row18_col5,#T_099b9_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_099b9_row0_col1,#T_099b9_row0_col2,#T_099b9_row0_col3,#T_099b9_row0_col4,#T_099b9_row2_col5,#T_099b9_row12_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_099b9_row0_col7,#T_099b9_row1_col7,#T_099b9_row2_col7,#T_099b9_row3_col7,#T_099b9_row4_col7,#T_099b9_row5_col7,#T_099b9_row7_col7,#T_099b9_row10_col7,#T_099b9_row11_col7,#T_099b9_row14_col7,#T_099b9_row16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_099b9_row6_col7,#T_099b9_row8_col7,#T_099b9_row9_col7,#T_099b9_row12_col7,#T_099b9_row13_col7,#T_099b9_row15_col7,#T_099b9_row17_col7,#T_099b9_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_099b9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_099b9_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_099b9_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_099b9_row0_col1" class="data row0 col1" >5.7147</td>
#                         <td id="T_099b9_row0_col2" class="data row0 col2" >89.3076</td>
#                         <td id="T_099b9_row0_col3" class="data row0 col3" >9.3698</td>
#                         <td id="T_099b9_row0_col4" class="data row0 col4" >0.8025</td>
#                         <td id="T_099b9_row0_col5" class="data row0 col5" >0.5641</td>
#                         <td id="T_099b9_row0_col6" class="data row0 col6" >1.3170</td>
#                         <td id="T_099b9_row0_col7" class="data row0 col7" >0.3233</td>
#             </tr>
#             <tr>
#                         <th id="T_099b9_level0_row1" class="row_heading level0 row1" >gbr</th>
#                         <td id="T_099b9_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_099b9_row1_col1" class="data row1 col1" >6.2444</td>
#                         <td id="T_099b9_row1_col2" class="data row1 col2" >102.5924</td>
#                         <td id="T_099b9_row1_col3" class="data row1 col3" >9.9875</td>
#                         <td id="T_099b9_row1_col4" class="data row1 col4" >0.7754</td>
#                         <td id="T_099b9_row1_col5" class="data row1 col5" >0.6639</td>
#                         <td id="T_099b9_row1_col6" class="data row1 col6" >1.9808</td>
#                         <td id="T_099b9_row1_col7" class="data row1 col7" >0.0233</td>
#             </tr>
#             <tr>
#                         <th id="T_099b9_level0_row2" class="row_heading level0 row2" >et</th>
#                         <td id="T_099b9_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#                         <td id="T_099b9_row2_col1" class="data row2 col1" >5.7412</td>
#                         <td id="T_099b9_row2_col2" class="data row2 col2" >102.3736</td>
#                         <td id="T_099b9_row2_col3" class="data row2 col3" >10.0943</td>
#                         <td id="T_099b9_row2_col4" class="data row2 col4" >0.7708</td>
#                         <td id="T_099b9_row2_col5" class="data row2 col5" >0.4768</td>
#                         <td id="T_099b9_row2_col6" class="data row2 col6" >0.8370</td>
#                         <td id="T_099b9_row2_col7" class="data row2 col7" >0.0733</td>
#             </tr>
#             <tr>
#                         <th id="T_099b9_level0_row3" class="row_heading level0 row3" >rf</th>
#                         <td id="T_099b9_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#                         <td id="T_099b9_row3_col1" class="data row3 col1" >6.1068</td>
#                         <td id="T_099b9_row3_col2" class="data row3 col2" >103.4153</td>
#                         <td id="T_099b9_row3_col3" class="data row3 col3" >10.1381</td>
#                         <td id="T_099b9_row3_col4" class="data row3 col4" >0.7681</td>
#                         <td id="T_099b9_row3_col5" class="data row3 col5" >0.5948</td>
#                         <td id="T_099b9_row3_col6" class="data row3 col6" >1.5098</td>
#                         <td id="T_099b9_row3_col7" class="data row3 col7" >0.0867</td>
#             </tr>
#             <tr>
#                         <th id="T_099b9_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#                         <td id="T_099b9_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_099b9_row4_col1" class="data row4 col1" >6.3669</td>
#                         <td id="T_099b9_row4_col2" class="data row4 col2" >107.7516</td>
#                         <td id="T_099b9_row4_col3" class="data row4 col3" >10.2570</td>
#                         <td id="T_099b9_row4_col4" class="data row4 col4" >0.7627</td>

# %%
concat_results = pd.concat(all_results,axis=0)
concat_results.head()
# Out:
#                        Model     MAE      MSE    RMSE      R2   RMSLE    MAPE  \
# catboost  CatBoost Regressor  4.0107  43.0801  6.5255  0.9186  0.3801  2.7826
# catboost  CatBoost Regressor  2.5838  19.1161  4.3701  0.8763  0.3598  0.5105
# catboost  CatBoost Regressor  2.4935  16.2214  3.9899  0.8139  0.4421  0.9328
# catboost  CatBoost Regressor  5.7147  89.3076  9.3698  0.8025  0.5641  1.3170
#
#           TT (Sec) time_series
# catboost    0.3300          MA
# catboost    0.3100          ME
# catboost    0.3033          VT
# catboost    0.3267          CT

# %% [markdown]
# Without any hyperparameter tuning, pycaret has determined that a CatBoost Regressor produced the best model metrics for Massachusetts, Maine, and Connecticut, and a Random Forest Regressor produced the best model metrics for Vermont. The top three performing models (using $R^2$ as the evaluation metric) on the entire dataset (including all four states) were: CatBoost Regressor, Random Forest Regressor, and Gradient Boosting Regressor (in that order).
#
# Let's try one-hot-encoding some, and then all, of the categorical columns in the dataset and see if that helps or hurts model performance.

# %% [markdown]
# ***

# %% [markdown]
# ## pycaret: One-hot-encoding categorical column: 'state_id'

# %% [markdown]
# While a CatBoost Regressor would certainly be able to accomodate our categorical columns, most other ML models can't handle category objects. Let's try one-hot-encoding the `state_id` column and compare pycaret's top performing models and metrics.

# %%
#one-hot-encode data
one_hot_encoded_data = pd.get_dummies(df, columns = ['state_id'])

# %%
one_hot_encoded_data
# Out:
#            date  Avg_Temp(F)  Conf_Cases  day_of_week  day_of_year  Year  \
# 0    2020-03-01        26.42         1.0            6           61  2020
# 1    2020-03-02        36.50         1.0            0           62  2020
# 2    2020-03-03        55.94         1.0            1           63  2020
# 3    2020-03-04        46.94         2.0            2           64  2020
# 4    2020-03-05        42.98         8.0            3           65  2020
# ...         ...          ...         ...          ...          ...   ...
# 2170 2021-07-20        75.02        73.0            1          201  2021
# 2171 2021-07-21        75.02       228.0            2          202  2021
# 2172 2021-07-22        71.42       295.0            3          203  2021
# 2173 2021-07-23        71.96       212.0            4          204  2021
# 2174 2021-07-24        70.70       196.0            5          205  2021
#
#       Month  Day  new_case_percent_pop*  PRCP_lag7wks  state_id_CT  \
# 0         3    1               0.014225     15.547836            0
# 1         3    2               0.014225     38.293482            0
# 2         3    3               0.014225     31.223697            0
# 3         3    4               0.028450     38.563755            0
# 4         3    5               0.113799     34.239380            0
# ...     ...  ...                    ...           ...          ...
# 2170      7   20               2.024435     25.929410            1
# 2171      7   21               6.322894     17.360225            1
# 2172      7   22               8.180937     17.332493            1
# 2173      7   23               5.879182      0.000000            1
# 2174      7   24               5.435470      0.000000            1
#
#       state_id_MA  state_id_ME  state_id_VT
# 0               1            0            0
# 1               1            0            0
# 2               1            0            0
# 3               1            0            0
# 4               1            0            0
# ...           ...          ...          ...
# 2170            0            0            0
# 2171            0            0            0
# 2172            0            0            0
# 2173            0            0            0
# 2174            0            0            0
#
# [2028 rows x 14 columns]

# %%
s = setup(one_hot_encoded_data, target ='new_case_percent_pop*', train_size = 0.8,
            data_split_shuffle = True, fold = 3,
            ignore_features = ['date', 'Conf_Cases'],
            numeric_features = ['day_of_year', 'Year', 'Avg_Temp(F)', 'PRCP_lag7wks'],
            categorical_features = ['Month', 'day_of_week', 'state_id_MA', 'state_id_CT', 'state_id_VT', 'state_id_ME'],
            silent = True, verbose = False, session_id = 123, normalize=False)
    # compare all models and select best one based on MAE
best_model = compare_models(sort = 'R2', verbose=False)
    
    # capture the compare result grid and store best model in list
p = pull().iloc[0:1]
p['time_series'] = str(i)
all_results.append(p)
best = compare_models(sort = 'R2')
best
# Out:
# <style  type="text/css" >
#     #T_43cca_ th {
#           text-align: left;
#     }#T_43cca_row0_col0,#T_43cca_row0_col1,#T_43cca_row0_col5,#T_43cca_row0_col6,#T_43cca_row1_col0,#T_43cca_row1_col2,#T_43cca_row1_col3,#T_43cca_row1_col4,#T_43cca_row2_col0,#T_43cca_row2_col1,#T_43cca_row2_col2,#T_43cca_row2_col3,#T_43cca_row2_col4,#T_43cca_row2_col5,#T_43cca_row2_col6,#T_43cca_row3_col0,#T_43cca_row3_col1,#T_43cca_row3_col2,#T_43cca_row3_col3,#T_43cca_row3_col4,#T_43cca_row3_col5,#T_43cca_row3_col6,#T_43cca_row4_col0,#T_43cca_row4_col1,#T_43cca_row4_col2,#T_43cca_row4_col3,#T_43cca_row4_col4,#T_43cca_row4_col5,#T_43cca_row4_col6,#T_43cca_row5_col0,#T_43cca_row5_col1,#T_43cca_row5_col2,#T_43cca_row5_col3,#T_43cca_row5_col4,#T_43cca_row5_col5,#T_43cca_row5_col6,#T_43cca_row6_col0,#T_43cca_row6_col1,#T_43cca_row6_col2,#T_43cca_row6_col3,#T_43cca_row6_col4,#T_43cca_row6_col5,#T_43cca_row6_col6,#T_43cca_row7_col0,#T_43cca_row7_col1,#T_43cca_row7_col2,#T_43cca_row7_col3,#T_43cca_row7_col4,#T_43cca_row7_col5,#T_43cca_row7_col6,#T_43cca_row8_col0,#T_43cca_row8_col1,#T_43cca_row8_col2,#T_43cca_row8_col3,#T_43cca_row8_col4,#T_43cca_row8_col5,#T_43cca_row8_col6,#T_43cca_row9_col0,#T_43cca_row9_col1,#T_43cca_row9_col2,#T_43cca_row9_col3,#T_43cca_row9_col4,#T_43cca_row9_col5,#T_43cca_row9_col6,#T_43cca_row10_col0,#T_43cca_row10_col1,#T_43cca_row10_col2,#T_43cca_row10_col3,#T_43cca_row10_col4,#T_43cca_row10_col5,#T_43cca_row10_col6,#T_43cca_row11_col0,#T_43cca_row11_col1,#T_43cca_row11_col2,#T_43cca_row11_col3,#T_43cca_row11_col4,#T_43cca_row11_col5,#T_43cca_row11_col6,#T_43cca_row12_col0,#T_43cca_row12_col1,#T_43cca_row12_col2,#T_43cca_row12_col3,#T_43cca_row12_col4,#T_43cca_row12_col5,#T_43cca_row12_col6,#T_43cca_row13_col0,#T_43cca_row13_col1,#T_43cca_row13_col2,#T_43cca_row13_col3,#T_43cca_row13_col4,#T_43cca_row13_col5,#T_43cca_row13_col6,#T_43cca_row14_col0,#T_43cca_row14_col1,#T_43cca_row14_col2,#T_43cca_row14_col3,#T_43cca_row14_col4,#T_43cca_row14_col5,#T_43cca_row14_col6,#T_43cca_row15_col0,#T_43cca_row15_col1,#T_43cca_row15_col2,#T_43cca_row15_col3,#T_43cca_row15_col4,#T_43cca_row15_col5,#T_43cca_row15_col6,#T_43cca_row16_col0,#T_43cca_row16_col1,#T_43cca_row16_col2,#T_43cca_row16_col3,#T_43cca_row16_col4,#T_43cca_row16_col5,#T_43cca_row16_col6,#T_43cca_row17_col0,#T_43cca_row17_col1,#T_43cca_row17_col2,#T_43cca_row17_col3,#T_43cca_row17_col4,#T_43cca_row17_col5,#T_43cca_row17_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_43cca_row0_col2,#T_43cca_row0_col3,#T_43cca_row0_col4,#T_43cca_row1_col1,#T_43cca_row1_col5,#T_43cca_row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_43cca_row0_col7,#T_43cca_row1_col7,#T_43cca_row2_col7,#T_43cca_row3_col7,#T_43cca_row4_col7,#T_43cca_row5_col7,#T_43cca_row6_col7,#T_43cca_row9_col7,#T_43cca_row10_col7,#T_43cca_row11_col7,#T_43cca_row12_col7,#T_43cca_row13_col7,#T_43cca_row15_col7,#T_43cca_row16_col7,#T_43cca_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_43cca_row7_col7,#T_43cca_row8_col7,#T_43cca_row14_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_43cca_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43cca_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_43cca_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_43cca_row0_col1" class="data row0 col1" >3.6992</td>
#                         <td id="T_43cca_row0_col2" class="data row0 col2" >42.4709</td>
#                         <td id="T_43cca_row0_col3" class="data row0 col3" >6.4682</td>
#                         <td id="T_43cca_row0_col4" class="data row0 col4" >0.8706</td>
#                         <td id="T_43cca_row0_col5" class="data row0 col5" >0.4443</td>
#                         <td id="T_43cca_row0_col6" class="data row0 col6" >1.1091</td>
#                         <td id="T_43cca_row0_col7" class="data row0 col7" >0.4167</td>
#             </tr>
#             <tr>
#                         <th id="T_43cca_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_43cca_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_43cca_row1_col1" class="data row1 col1" >3.5719</td>
#                         <td id="T_43cca_row1_col2" class="data row1 col2" >46.8475</td>
#                         <td id="T_43cca_row1_col3" class="data row1 col3" >6.7935</td>
#                         <td id="T_43cca_row1_col4" class="data row1 col4" >0.8563</td>
#                         <td id="T_43cca_row1_col5" class="data row1 col5" >0.3503</td>
#                         <td id="T_43cca_row1_col6" class="data row1 col6" >0.6372</td>
#                         <td id="T_43cca_row1_col7" class="data row1 col7" >0.4600</td>
#             </tr>
#             <tr>
#                         <th id="T_43cca_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_43cca_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_43cca_row2_col1" class="data row2 col1" >3.8124</td>
#                         <td id="T_43cca_row2_col2" class="data row2 col2" >50.5702</td>
#                         <td id="T_43cca_row2_col3" class="data row2 col3" >7.0242</td>
#                         <td id="T_43cca_row2_col4" class="data row2 col4" >0.8474</td>
#                         <td id="T_43cca_row2_col5" class="data row2 col5" >0.3959</td>
#                         <td id="T_43cca_row2_col6" class="data row2 col6" >0.8624</td>
#                         <td id="T_43cca_row2_col7" class="data row2 col7" >0.1333</td>
#             </tr>
#             <tr>
#                         <th id="T_43cca_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#                         <td id="T_43cca_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_43cca_row3_col1" class="data row3 col1" >4.0498</td>
#                         <td id="T_43cca_row3_col2" class="data row3 col2" >52.3772</td>
#                         <td id="T_43cca_row3_col3" class="data row3 col3" >7.1780</td>
#                         <td id="T_43cca_row3_col4" class="data row3 col4" >0.8407</td>
#                         <td id="T_43cca_row3_col5" class="data row3 col5" >0.4722</td>
#                         <td id="T_43cca_row3_col6" class="data row3 col6" >1.3756</td>
#                         <td id="T_43cca_row3_col7" class="data row3 col7" >0.1833</td>
#             </tr>
#             <tr>
#                         <th id="T_43cca_level0_row4" class="row_heading level0 row4" >xgboost</th>
#                         <td id="T_43cca_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_43cca_row4_col1" class="data row4 col1" >4.0827</td>
#                         <td id="T_43cca_row4_col2" class="data row4 col2" >54.5935</td>
#                         <td id="T_43cca_row4_col3" class="data row4 col3" >7.3343</td>
#                         <td id="T_43cca_row4_col4" class="data row4 col4" >0.8333</td>
#                         <td id="T_43cca_row4_col5" class="data row4 col5" >0.4676</td>
#                         <td id="T_43cca_row4_col6" class="data row4 col6" >1.1222<

# %% [markdown]
# Interestingly, we see a somewhat significant improvement in $R^2$ when we one-hot-encode the `state_id` column. It also appears that the Extra Trees Regressor now outperforms the Gradient Boosting Regressor.
#
# Let's check and see if one-hot-encoding the other categorical columns continues to improve model performance!

# %%
# save the data to a new csv file
#one_hot_encoded_data.to_csv('ohe_data.csv')

# %% [markdown]
# ## pycaret: One-hot-encoding all categorical data: state_id, Month, day_of_week

# %% [markdown]
# Let's now one-hot-encode each of our categorical columns (`state_id`, `Month`, and `day_of_week`) and re-run pycaret to see if we can further improve the model metrics.

# %%
#one-hot-encode data
one_hot_encoded_data3 = pd.get_dummies(df, columns = ['state_id', 'Month', 'day_of_week'])

# %%
one_hot_encoded_data3.columns.
# Out:
#   File "<ipython-input-74-b61ab97cad98>", line 1
#     one_hot_encoded_data3.columns.
#                                   ^
# SyntaxError: invalid syntax

# %%
s = setup(one_hot_encoded_data3, target ='new_case_percent_pop*', train_size = 0.8,
            data_split_shuffle = True, fold = 3,
            ignore_features = ['date', 'Conf_Cases'],
            numeric_features = ['day_of_year', 'Year', 'Avg_Temp(F)', 'PRCP_lag7wks'],
            categorical_features = ['state_id_CT', 'state_id_MA', 'state_id_ME',
                                       'state_id_VT', 'Month_1', 'Month_2', 'Month_3', 'Month_4', 'Month_5',
                                       'Month_6', 'Month_7', 'Month_8', 'Month_9', 'Month_10', 'Month_11',
                                       'Month_12', 'day_of_week_0', 'day_of_week_1', 'day_of_week_2',
                                       'day_of_week_3', 'day_of_week_4', 'day_of_week_5', 'day_of_week_6'],
            silent = True, verbose = False, session_id = 123, normalize=False)
    # compare all models and select best one based on MAE
best_model = compare_models(sort = 'R2', verbose=False)
    
    # capture the compare result grid and store best model in list
p = pull().iloc[0:1]
p['time_series'] = str(i)
all_results.append(p)
best = compare_models(sort = 'R2')
best

# %% [markdown]
# Even better! One-hot-encoding all three categorical columns produced the best model metrics yet! Let's save the dataset with these columns one-hot-encoded and begin tuning the hyperparameters of a CatBoost Regressor, Extra Trees Regressor, and Random Forest Regressor to feed into a Voting Regressor in the next steps.

# %%
# save the data to a new csv file
#one_hot_encoded_data3.to_csv('ohe_data_with_lag7_PRCP.csv')

# %%
len(one_hot_encoded_data3.columns)

# %% [markdown]
# *****

# %%
'''
s = setup(one_hot_encoded_data, target ='new_case_percent_pop*', train_size = 0.8,
            data_split_shuffle = True, fold = 3,
            ignore_features = ['date', 'Conf_Cases'],
            numeric_features = ['day_of_year', 'Year', 'Avg_Temp(F)'],
            categorical_features = ['Month', 'day_of_week', 'state_id_MA', 'state_id_CT', 'state_id_VT', 'state_id_ME'],
            silent = True, verbose = False, session_id = 123, normalize=True)
    # compare all models and select best one based on MAE
best_model = compare_models(sort = 'R2', verbose=False)
    
    # capture the compare result grid and store best model in list
p = pull().iloc[0:1]
p['time_series'] = str(i)
all_results.append(p)
best = compare_models(sort = 'R2')
best
'''
